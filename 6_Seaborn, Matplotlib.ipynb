# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data = df, y = 'tip', x = 'total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize = (10, 2))
sns.lineplot(data = df['tip'].head(50))
# Out:
# <Axes: ylabel='tip'>

# %%
sns.relplot(data = df, x = 'tip', y = 'total_bill')

# %%
sns.relplot(data = df, x = 'tip', y = 'total_bill', hue = 'smoker')

# %%
sns.relplot(data = df, x = 'tip', y = 'total_bill', hue = 'sex')

# %%
sns.relplot(data = df, x = 'tip', y = 'total_bill', hue = 'size')

# %%
sns.relplot(data = df, x = 'tip', y = 'total_bill', hue = 'time')

# %%
sns.relplot(data = df, x = 'tip', y = 'total_bill', style = 'time')

# %%
sns.relplot(data = df, x = 'tip', y = 'total_bill', style = 'time')

# %%
sns.relplot(data = df, x = 'tip', y = 'total_bill', style = 'size')

# %%
df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.relplot(data = df, x = 'tip', y = 'total_bill', style = 'time', hue = 'sex')

# %%
df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.countplot(data = df, x = 'size', color = 'r')
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
for i in df.columns:
    plt.figure(figsize = (10, 5))
    sns.countplot(data = df, x = i)
    plt.show()

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# relation

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df[['total_bill', 'tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
df1 = sns.load_dataset('taxis')

# %%
df1.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df1[['passengers', 'distance', 'fare', 'tip', 'tolls', 'total']]
# Out:
#       passengers  distance  fare   tip  tolls  total
# 0              1      1.60   7.0  2.15    0.0  12.95
# 1              1      0.79   5.0  0.00    0.0   9.30
# 2              1      1.37   7.5  2.36    0.0  14.16
# 3              1      7.70  27.0  6.15    0.0  36.95
# 4              3      2.16   9.0  1.10    0.0  13.40
# ...          ...       ...   ...   ...    ...    ...
# 6428           1      0.75   4.5  1.06    0.0   6.36
# 6429           1     18.74  58.0  0.00    0.0  58.80
# 6430           1      4.14  16.0  0.00    0.0  17.30
# 6431           1      1.12   6.0  0.00    0.0   6.80
# 6432           1      3.85  15.0  3.36    0.0  20.16
#
# [6433 rows x 6 columns]

# %%
df1[['passengers', 'distance', 'fare', 'tip', 'tolls', 'total']].corr()
# Out:
#             passengers  distance      fare       tip     tolls     total
# passengers    1.000000  0.009411  0.007637  0.021099 -0.002903  0.015708
# distance      0.009411  1.000000  0.920108  0.452589  0.635267  0.904676
# fare          0.007637  0.920108  1.000000  0.488612  0.609307  0.974358
# tip           0.021099  0.452589  0.488612  1.000000  0.413619  0.646186
# tolls        -0.002903  0.635267  0.609307  0.413619  1.000000  0.683142
# total         0.015708  0.904676  0.974358  0.646186  0.683142  1.000000

# %%
sns.heatmap(df1[['passengers', 'distance', 'fare', 'tip', 'tolls', 'total']].corr(), annot = True)
# Out:
# <Axes: >
