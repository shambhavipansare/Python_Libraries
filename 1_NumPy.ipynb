# %%
import numpy as np

# %%
np.median([12,31,15,26])                # calculates median of the data
# Out:
# 20.5

# %%
np.mean([12,31,15,26])                  # calculates mean of the given data
# Out:
# 21.0

# %%
np.median([12,31,15,26,120])            # median of data including outlier
# Out:
# 26.0

# %%
np.mean([12,31,15,26,120])              # mean of data including outlier
# Out:
# 40.8

# %%
np.random.randint([12,31,15,26,120])
# Out:
# array([ 6, 18,  7, 10, 13])

# %%
np.random.randint(10,50,5)
# Out:
# array([13, 17, 22, 17, 10])

# %%
l = [1, 2, 3, 4]

# %%
r1 = np.array(l)                       # create array of list l

# %%
r1
# Out:
# array([1, 2, 3, 4])

# %%
r1.ndim                                # no. of dimensions of array
# Out:
# 1

# %%
l2 = [[1, 2, 3, 4, 5], [10, 20, 30, 40, 50]]     # 2 brackets for 2 dimensional array

# %%
r2 = np.array(l2)

# %%
r2
# Out:
# array([[ 1,  2,  3,  4,  5],
#        [10, 20, 30, 40, 50]])

# %%
r2.ndim
# Out:
# 2

# %%
l3 = [[[10, 20, 30], [100, 200, 300], [1000, 2000, 3000]]]

# %%
np.array(l3)
# Out:
# array([[[  10,   20,   30],
#         [ 100,  200,  300],
#         [1000, 2000, 3000]]])
